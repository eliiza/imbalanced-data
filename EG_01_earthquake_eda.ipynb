# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import LabelEncoder
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer
from sklearn.impute import KNNImputer

# %%
quake_frame = pd.read_csv('data/consolidated_data.csv')

# %%
quake_frame.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3272774 entries, 0 to 3272773
# Data columns (total 23 columns):
#  #   Column           Dtype
# ---  ------           -----
#  0   Unnamed: 0       int64
#  1   time             object
#  2   latitude         float64
#  3   longitude        float64
#  4   depth            float64
#  5   mag              float64
#  6   magType          object
#  7   nst              float64
#  8   gap              float64
#  9   dmin             float64
#  10  rms              float64
#  11  net              object
#  12  id               object
#  13  updated          object
#  14  place            object
#  15  type             object
#  16  horizontalError  float64
#  17  depthError       float64
#  18  magError         float64
#  19  magNst           float64
#  20  status           object
#  21  locationSource   object
#  22  magSource        object
# dtypes: float64(12), int64(1), object(10)
# memory usage: 574.3+ MB

# %%
quake_frame.head()
# Out:
#     latitude   longitude  depth   mag magType  nst  gap  dmin  rms net  \
# 0  37.003502 -117.996834    0.0  0.00      mh  0.0  NaN   NaN  NaN  ci
# 1  35.642788 -120.933601    5.0  1.99      mh  2.0  NaN   NaN  NaN  ci
# 2  34.164520 -118.185036    0.0  0.00      mh  NaN  NaN   NaN  NaN  ci
# 3  33.836494 -116.781868    0.0  0.00      mh  NaN  NaN   NaN  NaN  ci
# 4  33.208477 -115.476997    5.0  0.00      mh  NaN  NaN   NaN  NaN  ci
#
#          type  horizontalError  depthError  magError  magNst    status  \
# 0  sonic boom              NaN         NaN       NaN     0.0  reviewed
# 1  earthquake              NaN         NaN       NaN     0.0  reviewed
# 2  earthquake              NaN         NaN       NaN     0.0  reviewed
# 3  sonic boom              NaN         NaN       NaN     0.0  reviewed
# 4  sonic boom              NaN         NaN       NaN     0.0  reviewed
#
#   locationSource magSource  simple_label  has_null
# 0             ci        ci          True      True
# 1             ci        ci         False      True
# 2             ci        ci         False      True
# 3             ci        ci          True      True
# 4             ci        ci          True      True

# %%
quake_frame.type.value_counts()['earthquake']/len(quake_frame.index)
# Out:
# 0.9729571916667634

# %% [markdown]
# Righto, so 97.3% of our dataset consists of earthquakes. That is definitely imbalanced.

# %%
var_cols = quake_frame.columns
var_cols
# Out:
# Index(['Unnamed: 0', 'time', 'latitude', 'longitude', 'depth', 'mag',
#        'magType', 'nst', 'gap', 'dmin', 'rms', 'net', 'id', 'updated', 'place',
#        'type', 'horizontalError', 'depthError', 'magError', 'magNst', 'status',
#        'locationSource', 'magSource'],
#       dtype='object')

# %%
quake_frame.isna().sum()
# Out:
# Unnamed: 0               0
# time                     0
# latitude                 0
# longitude                0
# depth                    9
# mag                 156449
# magType             167407
# nst                 881566
# gap                 838549
# dmin               1346742
# rms                 211653
# net                      0
# id                       0
# updated                  0
# place                   11
# type                     0
# horizontalError    1531963
# depthError          606685
# magError           1781012
# magNst              988917
# status                   1
# locationSource           0
# magSource                0
# dtype: int64

# %% [markdown]
# Okay, let's kick this off. We've had a look around the dataset and there are quite a few nans and values that appear to be either so numerous or varied that they aren't useful (like time and updated, while earthquakes might not be independent, we're not looking at a timeseries) or they are available in multiple formats (longitude/latitude and place).
# Other variables are not clear, like the Source ones which appear similar to the net, but not the same.

# %% [markdown]
# Right, so it looks like the source of the information is a key part of the information about what a thing is. So they should all be kept. The dmin variable looks like about 1/3 of the whole dataset has nans. Similar to horizontalError and magError. DepthError and magNst don't seem to fare much better. First dumb idea, take out any columns that are too hard to recode or useless anyway, run a model, see what happens.

# %%
quake_frame.drop(['id', 'Unnamed: 0', 'place', 'time', 'updated'], inplace=True, axis=1)

# %% [markdown]
# Brilliant. Now, there are a few interesting things to test here.
# What's the connection between the nans and the non-earthquake types? Are the nans equally distributed?
# What can we say about the correlation between the type and the number of nans? These and more questions are still to answer!

# %%
quake_frame['simple_label'] = quake_frame['type'] != 'earthquake'

# %%
quake_frame['has_null'] = quake_frame.isna().sum(axis=1)

# %%
quake_frame['simple_label'].corr(quake_frame['has_null'])
# Out:
# -0.033550227623335906

# %% [markdown]
# Right, now that's awesome. At first glance, there's no reason to believe that there's a common thread underneath at least whether or not something is an earthquake and whether it has NaNs. Cool. Okay, so I'd say we have a look at a few distributions. Make sure max and min are okay etc.

# %%
quake_frame.describe().transpose()
# Out:
#                      count        mean          std      min        25%  \
# latitude         3272774.0   35.720738    20.256723  -84.422   34.11800
# longitude        3272774.0  -92.856671    80.553255 -179.999 -122.79583
# depth            3272765.0   22.334946    56.320328  -10.000    3.00200
# mag              3116325.0    1.878941     1.352506   -9.990    0.97000
# nst              2391208.0   15.601496    26.606866    0.000    5.00000
# gap              2434225.0  130.487608    69.710621    0.000   79.00000
# dmin             1926032.0    0.255999     1.333459    0.000    0.02093
# rms              3061121.0    0.315205     0.399901   -1.000    0.06000
# horizontalError  1740811.0    1.266841     3.168282    0.000    0.30000
# depthError       2666089.0    5.640320  1167.801181   -1.000    0.49000
# magError         1491762.0    0.166893     0.147429    0.000    0.09000
# magNst           2283857.0   12.607386    21.127239    0.000    3.00000
# has_null         3272774.0    2.600532     2.747433    0.000    0.00000
#
#                         50%         75%          max
# latitude          37.576167   42.258667       87.265
# longitude       -118.811167 -115.454167      180.000
# depth              7.155000   15.000000      735.800
# mag                1.500000    2.460000        9.100
# nst               10.000000   18.000000      934.000
# gap              115.000000  168.260000      360.000
# dmin               0.051350    0.116000      141.160
# rms                0.150000    0.480000      104.330
# horizontalError    0.480000    0.930000      280.600
# depthError         0.960000    2.760000  1773552.500
# magError           0.142000    0.210000        6.110
# magNst             7.000000   14.000000      941.000
# has_null           1.000000    6.000000       11.000

# %% [markdown]
# Okay, the locations are all within sensible bounds. So is the depth. Now let's check whether there's a link between what 'type' there is and the gap. Let's see which types have no gaps.
# I think it'll be sensible to clip the depthError, though - 17 million meters is a bit much.

# %%
sum(quake_frame['gap'].isna())
# Out:
# 838549

# %%
quake_frame.groupby('type').count()
# Out:
#                             latitude  longitude    depth      mag  magType  \
# type
# Rock Slide                         1          1        1        1        1
# acoustic noise                     2          2        2        2        2
# building collapse                  5          5        5        0        0
# chemical explosion               392        392      392      369      369
# collapse                           1          1        1        1        1
# earthquake                   3184269    3184269  3184262  3034628  3023675
# eq                                 1          1        1        1        0
# experimental explosion             5          5        5        5        5
# explosion                      20133      20133    20133    20052    20050
# ice quake                       3951       3951     3951     3951     3951
# induced or triggered event         1          1        1        1        1
# landslide                         15         15       15        8        8
# meteorite                          1          1        1        1        1
# mine collapse                     33         33       33       27       27
# mining explosion                1240       1240     1240     1235     1235
# not reported                       3          3        3        3        3
# nuclear explosion                738        738      738      733      733
# other event                      517        517      517      517      517
# quarry                            17         17       17       17       17
# quarry blast                   60898      60898    60898    54464    54464
# rock burst                       180        180      180      180      179
# rockslide                          3          3        3        3        3
# sonic boom                       351        351      351      110      110
# sonicboom                          2          2        0        1        0
# volcanic eruption                 15         15       15       15       15
#
#                                 nst      gap     dmin      rms      net  \
# type
# Rock Slide                        1        1        0        1        1
# acoustic noise                    2        2        2        0        2
# building collapse                 0        0        0        0        5
# chemical explosion              386      385      384      385      392
# collapse                          0        0        0        1        1
# earthquake                  2312690  2354425  1866907  2973090  3184269
# eq                                0        0        0        0        1
# experimental explosion            0        5        5        5        5
# explosion                     16510    16496    15854    20044    20133
# ice quake                         0        5        5     3951     3951
# induced or triggered event        0        1        1        1        1
# landslide                        13       13       13       15       15
# meteorite                         0        0        0        1        1
# mine collapse                     0        6        6        7       33
# mining explosion                  0     1238     1238     1240     1240
# not reported                      3        3        3        0        3
# nuclear explosion               351      353      127      566      738
# other event                      40       40       40      505      517
# quarry                            4       17       17       14       17
# quarry blast                  60782    60810    41119    60810    60898
# rock burst                      113      119       22      177      180
# rockslide                         3        3        3        3        3
# sonic boom                      295      288      271      290      351
# sonicboom                         0        0        0        0        2
# volcanic eruption                15       15       15       15       15
#
#                             horizontalError  depthError  magError   magNst  \
# type
# Rock Slide                                0           0         0        0
# acoustic noise                            0           0         2        2
# building collapse                         0           0         0        0
# chemical explosion                      388         388       341      369
# collapse                                  1           1         1        1
# earthquake                          1688270     2604029   1444712  2210544
# eq                                        0           0         0        0
# experimental explosion                    5           5         5        5
# explosion                             15890       18916     16371    16525
# ice quake                                20        3951         7        7
# induced or triggered event                1           1         1        1
# landslide                                14          15         8        8
# meteorite                                 1           1         1        1
# mine collapse                             7           7         6        7
# mining explosion                       1025        1240      1223     1166
# not reported                              0           0         3        3
# nuclear explosion                       340         341       328      565
# other event                              39         505        38       52
# quarry                                   14          14        13       13
# quarry blast                          34702       36330     28642    54441
# rock burst                               10          22        22       24
# rockslide                                 3           3         3        3
# sonic boom                               66         305        35      105
# sonicboom                                 0           0         0        0
# volcanic eruption                        15          15         0       15
#
#                              status  locationSource  magSource  simple_label  \
# type
# Rock Slide                        1               1          1             1
# acoustic noise                    2               2          2             2
# building collapse                 5               5          5             5
# chemical explosion              392             392        392           392
# collapse                          1               1          1             1
# earthquake                  3184269         3184269    3184269       3184269
# eq                                0               1          1             1
# experimental explosion            5               5          5             5
# explosion                     20133           20133      20133         20133
# ice quake                      3951            3951       3951          3951
# induced or triggered event        1               1          1             1
# landslide                        15              15         15            15
# meteorite                         1               1          1             1
# mine collapse                    33              33         33            33
# mining explosion               1240            1240       1240          1240
# not reported                      3               3          3             3
# nuclear explosion               738             738        738           738
# other event                     517             517        517           517
# quarry                           17              17         17            17
# quarry blast                  60898           60898      60898         60898
# rock burst                      180             180        180           180
# rockslide                         3               3          3             3
# sonic boom                      351             351        351           351
# sonicboom                         2               2          2             2
# volcanic eruption                15              15         15            15
#
#                             has_null
# type
# Rock Slide                         1
# acoustic noise                     2
# building collapse                  5
# chemical explosion               392
# collapse                           1
# earthquake                   3184269
# eq                                 1
# experimental explosion             5
# explosion                      20133
# ice quake                       3951
# induced or triggered event         1
# landslide                         15
# meteorite                          1
# mine collapse                     33
# mining explosion                1240
# not reported                       3
# nuclear explosion                738
# other event                      517
# quarry                            17
# quarry blast                   60898
# rock burst                       180
# rockslide                          3
# sonic boom                       351
# sonicboom                          2
# volcanic eruption                 15

# %% [markdown]
# Cool. Again, it looks like there's no significant signature in the missing values by type. magError and horizontalError have the most missing types, and earthquakes are missing about 50% of each, as much as the two next biggest groups.
# This indicates that we have a fair chance to fix a whole bunch of values by running interpolation or imputation (or no chance whatsoever... but this will be a nice test!)

# %%
quake_frame.corr()
# Out:
#                  latitude  longitude     depth       mag       nst       gap  \
# latitude         1.000000  -0.451401 -0.296079 -0.507814 -0.158979  0.004029
# longitude       -0.451401   1.000000  0.210276  0.614025  0.247375 -0.003974
# depth           -0.296079   0.210276  1.000000  0.368889  0.187780  0.006451
# mag             -0.507814   0.614025  0.368889  1.000000  0.411418 -0.058773
# nst             -0.158979   0.247375  0.187780  0.411418  1.000000 -0.270720
# gap              0.004029  -0.003974  0.006451 -0.058773 -0.270720  1.000000
# dmin            -0.494358   0.389691  0.285692  0.415177 -0.051689  0.021445
# rms             -0.244619   0.484020  0.306884  0.647656  0.255584 -0.008536
# horizontalError -0.302554   0.335893  0.311279  0.386625 -0.132335  0.295077
# depthError       0.000085   0.006076  0.001451  0.003567 -0.043947  0.196087
# magError        -0.014073  -0.049341 -0.041375 -0.034934  0.029142  0.025157
# magNst          -0.061685   0.063904  0.081878  0.271055  0.533437 -0.248005
# simple_label     0.035748  -0.055807 -0.065932 -0.020237 -0.046812 -0.007296
# has_null        -0.031423   0.307779  0.251632  0.469126  0.040297  0.143001
#
#                      dmin       rms  horizontalError  depthError  magError  \
# latitude        -0.494358 -0.244619        -0.302554    0.000085 -0.014073
# longitude        0.389691  0.484020         0.335893    0.006076 -0.049341
# depth            0.285692  0.306884         0.311279    0.001451 -0.041375
# mag              0.415177  0.647656         0.386625    0.003567 -0.034934
# nst             -0.051689  0.255584        -0.132335   -0.043947  0.029142
# gap              0.021445 -0.008536         0.295077    0.196087  0.025157
# dmin             1.000000  0.315868         0.414551    0.052997 -0.032836
# rms              0.315868  1.000000         0.464142    0.002074 -0.021915
# horizontalError  0.414551  0.464142         1.000000    0.302583 -0.031127
# depthError       0.052997  0.002074         0.302583    1.000000  0.023596
# magError        -0.032836 -0.021915        -0.031127    0.023596  1.000000
# magNst           0.147570  0.109947         0.079172   -0.036658 -0.039358
# simple_label    -0.013744 -0.035358         0.027265    0.001106 -0.026695
# has_null         0.106397  0.576069         0.097424    0.003371  0.096193
#
#                    magNst  simple_label  has_null
# latitude        -0.061685      0.035748 -0.031423
# longitude        0.063904     -0.055807  0.307779
# depth            0.081878     -0.065932  0.251632
# mag              0.271055     -0.020237  0.469126
# nst              0.533437     -0.046812  0.040297
# gap             -0.248005     -0.007296  0.143001
# dmin             0.147570     -0.013744  0.106397
# rms              0.109947     -0.035358  0.576069
# horizontalError  0.079172      0.027265  0.097424
# depthError      -0.036658      0.001106  0.003371
# magError        -0.039358     -0.026695  0.096193
# magNst           1.000000     -0.010917  0.014536
# simple_label    -0.010917      1.000000 -0.033550
# has_null         0.014536     -0.033550  1.000000

# %% [markdown]
# Yeah, so it looks more like thinking that the NaNs would *not* give any information about the label was a bit hasty. However, to be precise, this is the number of NaNs, not whether or not there are any. So to truly test this, I'll transform this into a boolean column and run this again.

# %%
quake_frame['has_null'] = quake_frame['has_null'] > 0

# %%
quake_frame.corr().sort_values(by=['simple_label'], ascending=False)
# Out:
#                  latitude  longitude     depth       mag       nst       gap  \
# simple_label     0.035748  -0.055807 -0.065932 -0.020237 -0.046812 -0.007296
# latitude         1.000000  -0.451401 -0.296079 -0.507814 -0.158979  0.004029
# horizontalError -0.302554   0.335893  0.311279  0.386625 -0.132335  0.295077
# depthError       0.000085   0.006076  0.001451  0.003567 -0.043947  0.196087
# gap              0.004029  -0.003974  0.006451 -0.058773 -0.270720  1.000000
# magNst          -0.061685   0.063904  0.081878  0.271055  0.533437 -0.248005
# dmin            -0.494358   0.389691  0.285692  0.415177 -0.051689  0.021445
# mag             -0.507814   0.614025  0.368889  1.000000  0.411418 -0.058773
# magError        -0.014073  -0.049341 -0.041375 -0.034934  0.029142  0.025157
# rms             -0.244619   0.484020  0.306884  0.647656  0.255584 -0.008536
# has_null        -0.062753   0.256776  0.224449  0.370025 -0.054372  0.136791
# nst             -0.158979   0.247375  0.187780  0.411418  1.000000 -0.270720
# longitude       -0.451401   1.000000  0.210276  0.614025  0.247375 -0.003974
# depth           -0.296079   0.210276  1.000000  0.368889  0.187780  0.006451
#
#                      dmin       rms  horizontalError  depthError  magError  \
# simple_label    -0.013744 -0.035358         0.027265    0.001106 -0.026695
# latitude        -0.494358 -0.244619        -0.302554    0.000085 -0.014073
# horizontalError  0.414551  0.464142         1.000000    0.302583 -0.031127
# depthError       0.052997  0.002074         0.302583    1.000000  0.023596
# gap              0.021445 -0.008536         0.295077    0.196087  0.025157
# magNst           0.147570  0.109947         0.079172   -0.036658 -0.039358
# dmin             1.000000  0.315868         0.414551    0.052997 -0.032836
# mag              0.415177  0.647656         0.386625    0.003567 -0.034934
# magError        -0.032836 -0.021915        -0.031127    0.023596  1.000000
# rms              0.315868  1.000000         0.464142    0.002074 -0.021915
# has_null         0.176671  0.446177         0.227323    0.002267  0.126834
# nst             -0.051689  0.255584        -0.132335   -0.043947  0.029142
# longitude        0.389691  0.484020         0.335893    0.006076 -0.049341
# depth            0.285692  0.306884         0.311279    0.001451 -0.041375
#
#                    magNst  simple_label  has_null
# simple_label    -0.010917      1.000000 -0.039124
# latitude        -0.061685      0.035748 -0.062753
# horizontalError  0.079172      0.027265  0.227323
# depthError      -0.036658      0.001106  0.002267
# gap             -0.248005     -0.007296  0.136791
# magNst           1.000000     -0.010917 -0.003974
# dmin             0.147570     -0.013744  0.176671
# mag              0.271055     -0.020237  0.370025
# magError        -0.039358     -0.026695  0.126834
# rms              0.109947     -0.035358  0.446177
# has_null        -0.003974     -0.039124  1.000000
# nst              0.533437     -0.046812 -0.054372
# longitude        0.063904     -0.055807  0.256776
# depth            0.081878     -0.065932  0.224449

# %% [markdown]
# This is very interesting. It appears that the presence of nulls alone boosts the correlation into 4th place out of 17. So it is very indicative. A useful feature, then? Maybe for this dataset. A more thorough analysis would have to look for patterns in the NaNs as well, such as looking for a dependence on time etc.
# For now, it looks like there is some correlation that allows us to tell whether something is an earthquake or not from the dataset.
